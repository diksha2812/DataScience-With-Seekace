# %%
# read csv named "titanic.csv"
import pandas as pd
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Total number of missing values in each column of dataframe "df"
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Drop column i.e, Cabin from the dataframe "df"
df.drop(["Cabin","Name","PassengerId"], axis=1, inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
# Value count of column "Embarked"
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# Replacing null or empty values in column "Embarked" with S 
df["Embarked"].fillna("S", inplace = True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
# Checking weather the null values replaced or not 
df.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# finding mean of column "Age"
df.Age.mean()
# Out:
# 29.69911764705882

# %%
# Replacing null or empty values in column "Age" with mean value
df["Age"].fillna("29.6", inplace = True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male    22      1      0         A/5 21171   7.2500
# 1           1       1  female    38      1      0          PC 17599  71.2833
# 2           1       3  female    26      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female    35      1      0            113803  53.1000
# 4           0       3    male    35      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male    27      0      0            211536  13.0000
# 887         1       1  female    19      0      0            112053  30.0000
# 888         0       3  female  29.6      1      2        W./C. 6607  23.4500
# 889         1       1    male    26      0      0            111369  30.0000
# 890         0       3    male    32      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
# Again checking the missing values
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# There is no duplicate value in our Dataframe "df"
df.duplicated().sum()
# Out:
# 15

# %%
# Droping the duplicates values from the dataframe "df"
df.drop_duplicates(inplace = True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male    22      1      0         A/5 21171   7.2500
# 1           1       1  female    38      1      0          PC 17599  71.2833
# 2           1       3  female    26      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female    35      1      0            113803  53.1000
# 4           0       3    male    35      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male    27      0      0            211536  13.0000
# 887         1       1  female    19      0      0            112053  30.0000
# 888         0       3  female  29.6      1      2        W./C. 6607  23.4500
# 889         1       1    male    26      0      0            111369  30.0000
# 890         0       3    male    32      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass       SibSp       Parch        Fare
# count  876.000000  876.000000  876.000000  876.000000  876.000000
# mean     0.383562    2.301370    0.474886    0.372146   32.035354
# std      0.486531    0.837983    0.946843    0.801912   49.975363
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000    0.000000    0.000000   14.427100
# 75%      1.000000    3.000000    1.000000    0.000000   30.548950
# max      1.000000    3.000000    8.000000    6.000000  512.329200

# %%
# Correlation 
import matplotlib.pyplot as plt
import seaborn as sns
colormap = plt.cm.cubehelix_r
plt.figure(figsize=(16,12))

plt.title('correlation of numeric features', y=1.05, size=15)
sns.heatmap(df.corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'correlation of numeric features'}>

# %%
from sklearn.preprocessing import LabelEncoder
le_Sex = LabelEncoder()
le_Embarked = LabelEncoder()

# %%
df["Sex_n"] = le_Sex.fit_transform(df['Sex'])
df["Embarked_n"] = le_Embarked.fit_transform(df['Embarked']) 
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male    22      1      0         A/5 21171   7.2500
# 1           1       1  female    38      1      0          PC 17599  71.2833
# 2           1       3  female    26      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female    35      1      0            113803  53.1000
# 4           0       3    male    35      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male    27      0      0            211536  13.0000
# 887         1       1  female    19      0      0            112053  30.0000
# 888         0       3  female  29.6      1      2        W./C. 6607  23.4500
# 889         1       1    male    26      0      0            111369  30.0000
# 890         0       3    male    32      0      0            370376   7.7500
#
#     Embarked  Sex_n  Embarked_n
# ...

# %%
df.drop(["Sex","Embarked"],axis=1, inplace=True)
df
# Out:
#      Survived  Pclass   Age  SibSp  Parch            Ticket     Fare  Sex_n  \
# 0           0       3    22      1      0         A/5 21171   7.2500      1
# 1           1       1    38      1      0          PC 17599  71.2833      0
# 2           1       3    26      0      0  STON/O2. 3101282   7.9250      0
# 3           1       1    35      1      0            113803  53.1000      0
# 4           0       3    35      0      0            373450   8.0500      1
# ..        ...     ...   ...    ...    ...               ...      ...    ...
# 886         0       2    27      0      0            211536  13.0000      1
# 887         1       1    19      0      0            112053  30.0000      0
# 888         0       3  29.6      1      2        W./C. 6607  23.4500      0
# 889         1       1    26      0      0            111369  30.0000      1
# 890         0       3    32      0      0            370376   7.7500      1
#
#      Embarked_n
# 0             2
# 1             0
# ...

# %%
df.drop(["Ticket"],axis=1, inplace=True)
df
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_n  Embarked_n
# 0           0       3    22      1      0   7.2500      1           2
# 1           1       1    38      1      0  71.2833      0           0
# 2           1       3    26      0      0   7.9250      0           2
# 3           1       1    35      1      0  53.1000      0           2
# 4           0       3    35      0      0   8.0500      1           2
# ..        ...     ...   ...    ...    ...      ...    ...         ...
# 886         0       2    27      0      0  13.0000      1           2
# 887         1       1    19      0      0  30.0000      0           2
# 888         0       3  29.6      1      2  23.4500      0           2
# 889         1       1    26      0      0  30.0000      1           0
# 890         0       3    32      0      0   7.7500      1           1
#
# [876 rows x 8 columns]

# %%
inputs = df.drop(["Survived"],axis=1)
target = df["Survived"]

# %%
inputs
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Sex_n  Embarked_n
# 0         3    22      1      0   7.2500      1           2
# 1         1    38      1      0  71.2833      0           0
# 2         3    26      0      0   7.9250      0           2
# 3         1    35      1      0  53.1000      0           2
# 4         3    35      0      0   8.0500      1           2
# ..      ...   ...    ...    ...      ...    ...         ...
# 886       2    27      0      0  13.0000      1           2
# 887       1    19      0      0  30.0000      0           2
# 888       3  29.6      1      2  23.4500      0           2
# 889       1    26      0      0  30.0000      1           0
# 890       3    32      0      0   7.7500      1           1
#
# [876 rows x 7 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 876, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %%
model.fit(inputs, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs, target)
# Out:
# 0.9817351598173516

# %%
from sklearn.metrics import classification_report

predictions=model.predict(X_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       114
#            1       1.00      0.95      0.98        62
#
#     accuracy                           0.98       176
#    macro avg       0.99      0.98      0.98       176
# weighted avg       0.98      0.98      0.98       176
